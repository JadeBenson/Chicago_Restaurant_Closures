# %% [markdown]
# ## This

# %%
import pandas as pd
import csv
import os

# %% [markdown]
#  ## CHANGE to your API key
#  Where the key string is passed to YelpAPI(): change that to your own!!

# %%
from yelpapi import YelpAPI 
yelp_api = YelpAPI('Your API KEY')

# %% [markdown]
# Complete list of parameters and output can be found here:
# https://www.yelp.com/developers/documentation/v3/business_search

# %% [markdown]
# List and descriptions of output: https://www.yelp.com/developers/documentation/v3/business

# %% [markdown]
# ## import your csvs:
# load the folder in which they are held and iterate through that folder, appending each df to one another

# %%
#csv_loc = 'path to folder where your CSVs are stored'
#csv_loc = 'Users/sabinahartnett/Desktop/UChicago/CS_Winter2021/final-project-localgorithms/dummyCSV/'

csv_loc = 'CSVs/'
closed_loc = 'closed_wb/'
missing_loc = 'missing_wb/'
#change this to another name
out_file_yelp = "yelp_all.csv"
out_file_closed = "closed_all_wb.csv"
out_file_missing = "missing_all_wb.csv"

ALL_loc = 'combined/'
out_file_ALL = "all_combined_wb.csv"

# %%
#to clean all the data - create a folder of thefiles for closed businesses and be sure they are all listed as closed,
#then run over EVERYTHING to combine
def combine_csvs(folder_path, are_closed, ouput_filename):
    '''
    Parses through a folder in the remote location and creates
    a dataframe of all unique entries (prioritizing closed businesses),
    and outputs that DF as a CSV.
    
    Inputs:
        folder_path: path to folder with input csvs
        are_closed: whether to check that all businesses in those CSVs
            are closed ('is_closed' = True): will overwrite if not.
        output_filename: name of file to write out to (outside of CSV folder)
    
    Ouput:
        all_pd: a full pandas dataframe of all unique businesses from CSVs
        csv file: written out version of the full pandas DF.
    '''
    
    csv_os = os.listdir(folder_path)
    #note: order is whatever order the files exist in in the folder (likely alphabetic)
    all_pd= pd.DataFrame()
    
    for file_ in csv_os:
        df1 = pd.read_csv(folder_path + file_) #, index_col = 'Unnamed: 0')
        
        print("importing:", file_, "of length:", len(df1), "changing all businesses to closed = ", are_closed)
        
        if are_closed:
            df1['is_closed'] = True
        
        #note indecies won't line up so we have to overwrite them
        all_pd = pd.concat([all_pd, df1], axis = 0, join = 'outer', sort=True, ignore_index=True)
    
    #drop 'unnamed' column
    all_pd.drop(['Unnamed: 0'], axis = 1, errors = 'ignore', inplace = True)
    #businesses will be sorted by name and is_closed ('True' > 'False')
    all_pd.sort_values(by=['id', 'is_closed'], inplace = True)
    #remove the 'lower value' of the location: if one is 'True' keep that
    all_pd.drop_duplicates(subset = 'id', keep='last', inplace = True)
    
    all_pd.to_csv(ouput_filename, index = True)
    
    return all_pd

# %%
#combine_yelps = combine_csvs('CSVs/', False, "all_OG_yelp.csv")

# %%
yelp_DF = combine_csvs(csv_loc, False, out_file_yelp)
# Out:
# importing: egemen_all.csv of length: 8432 changing all businesses to closed =  False
# importing: .DS_Store of length: 0 changing all businesses to closed =  False
# importing: SH_all_business_query.csv of length: 2713 changing all businesses to closed =  False
# importing: mk_complete.csv of length: 8029 changing all businesses to closed =  False
# importing: all_Jade_data.csv of length: 2717 changing all businesses to closed =  False

# %%
closed_DF = combine_csvs(closed_loc, True, out_file_closed)
# Out:
# importing: yelp_results_from_now_closed_wb.csv of length: 539 changing all businesses to closed =  True
#    Unnamed: 0                                alias  business type  \
# 0           0         one-eleven-food-hall-chicago     Restaurant
# 1           1             karlas-kitchen-chicago-2     Restaurant
# 2           2  lincoln-quality-meat-market-chicago  Grocery Store
# 3           3         one-eleven-food-hall-chicago         Bakery
# 4           4                 taco-bell-chicago-52     Restaurant
#
#                                           categories  \
# 0   [{'alias': 'food_court', 'title': 'Food Court'}]
# 1  [{'alias': 'comfortfood', 'title': 'Comfort Fo...
# 2  [{'alias': 'meats', 'title': 'Meat Shops'}, {'...
# 3   [{'alias': 'food_court', 'title': 'Food Court'}]
# 4  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 41.6927953199255, 'longitude': -8...             NaN
# 1  {'latitude': 41.8703587635362, 'longitude': -8...  (773) 696-9166
# 2  {'latitude': 41.966542268579, 'longitude': -87...  (773) 561-4570
# 3  {'latitude': 41.6927953199255, 'longitude': -8...             NaN
# 4     {'latitude': 41.92586, 'longitude': -87.64034}             NaN
#
#                                                hours                      id  \
# 0  [{'open': [{'is_overnight': False, 'start': '0...  Sx3f7tuMO_TXUHtQjHYONw
# 1  [{'open': [{'is_overnight': False, 'start': '0...  1b2lFEiNRKpMsIYTqhqiKg
# 2  [{'open': [{'is_overnight': False, 'start': '1...  prRoQKojykTw15fPKnJfEA
# 3  [{'open': [{'is_overnight': False, 'start': '0...  Sx3f7tuMO_TXUHtQjHYONw
# 4  [{'open': [{'is_overnight': True, 'start': '09...  ju69jWsZFKmnW3iqYK1zYw
#
#                                            image_url  is_claimed  ...  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/LRHelk...       False  ...
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/oUuVgy...        True  ...
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/7zsW3v...        True  ...
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/LRHelk...       False  ...
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/X5qgU3...        True  ...
#
#                                             location  \
# 0  {'address1': '712 E 111th St', 'address2': '',...
# 1  {'address1': '819 S Pulaski Rd', 'address2': '...
# 2  {'address1': '4661 N Lincoln Ave', 'address2':...
# 3  {'address1': '712 E 111th St', 'address2': '',...
# 4  {'address1': '2407 N. Clark Street', 'address2...
#
#                                            messaging  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'url': 'https://www.yelp.com/raq/ju69jWsZFKmn...
#
#                           name         phone  \
# 0         one eleven food hall           NaN
# 1              Karla's Kitchen  1.773697e+10
# 2  Lincoln Quality Meat Market  1.773561e+10
# 3         one eleven food hall           NaN
# 4                    Taco Bell           NaN
#
#                                               photos price rating  \
# 0  ['https://s3-media4.fl.yelpcdn.com/bphoto/LRHe...   NaN    4.5
# 1  ['https://s3-media2.fl.yelpcdn.com/bphoto/oUuV...   NaN    3.0
# 2  ['https://s3-media1.fl.yelpcdn.com/bphoto/7zsW...    $$    4.0
# 3  ['https://s3-media4.fl.yelpcdn.com/bphoto/LRHe...   NaN    4.5
# 4  ['https://s3-media1.fl.yelpcdn.com/bphoto/X5qg...     $    3.5
#
#    review_count            transactions  \
# 0            23                      []
# 1             2  ['pickup', 'delivery']
# 2            56                      []
# 3            23                      []
# 4            22            ['delivery']
#
#                                                  url
# 0  https://www.yelp.com/biz/one-eleven-food-hall-...
# 1  https://www.yelp.com/biz/karlas-kitchen-chicag...
# 2  https://www.yelp.com/biz/lincoln-quality-meat-...
# 3  https://www.yelp.com/biz/one-eleven-food-hall-...
# 4  https://www.yelp.com/biz/taco-bell-chicago-52?...
#
# [5 rows x 21 columns]
# importing: .DS_Store of length: 0 changing all businesses to closed =  True
#   Unnamed: 0                                alias  business type  \
# 0          0         one-eleven-food-hall-chicago     Restaurant
# 1          1             karlas-kitchen-chicago-2     Restaurant
# 2          2  lincoln-quality-meat-market-chicago  Grocery Store
# 3          3         one-eleven-food-hall-chicago         Bakery
# 4          4                 taco-bell-chicago-52     Restaurant
#
#                                           categories  \
# 0   [{'alias': 'food_court', 'title': 'Food Court'}]
# 1  [{'alias': 'comfortfood', 'title': 'Comfort Fo...
# 2  [{'alias': 'meats', 'title': 'Meat Shops'}, {'...
# 3   [{'alias': 'food_court', 'title': 'Food Court'}]
# 4  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 41.6927953199255, 'longitude': -8...             NaN
# 1  {'latitude': 41.8703587635362, 'longitude': -8...  (773) 696-9166
# 2  {'latitude': 41.966542268579, 'longitude': -87...  (773) 561-4570
# 3  {'latitude': 41.6927953199255, 'longitude': -8...             NaN
# 4     {'latitude': 41.92586, 'longitude': -87.64034}             NaN
#
#                                                hours                      id  \
# 0  [{'open': [{'is_overnight': False, 'start': '0...  Sx3f7tuMO_TXUHtQjHYONw
# 1  [{'open': [{'is_overnight': False, 'start': '0...  1b2lFEiNRKpMsIYTqhqiKg
# 2  [{'open': [{'is_overnight': False, 'start': '1...  prRoQKojykTw15fPKnJfEA
# 3  [{'open': [{'is_overnight': False, 'start': '0...  Sx3f7tuMO_TXUHtQjHYONw
# 4  [{'open': [{'is_overnight': True, 'start': '09...  ju69jWsZFKmnW3iqYK1zYw
#
#                                            image_url is_claimed  ...  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/LRHelk...      False  ...
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/oUuVgy...       True  ...
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/7zsW3v...       True  ...
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/LRHelk...      False  ...
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/X5qgU3...       True  ...
#
#                                             location  \
# 0  {'address1': '712 E 111th St', 'address2': '',...
# 1  {'address1': '819 S Pulaski Rd', 'address2': '...
# 2  {'address1': '4661 N Lincoln Ave', 'address2':...
# 3  {'address1': '712 E 111th St', 'address2': '',...
# 4  {'address1': '2407 N. Clark Street', 'address2...
#
#                                            messaging  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'url': 'https://www.yelp.com/raq/ju69jWsZFKmn...
#
#                           name         phone  \
# 0         one eleven food hall           NaN
# 1              Karla's Kitchen  1.773697e+10
# 2  Lincoln Quality Meat Market  1.773561e+10
# 3         one eleven food hall           NaN
# 4                    Taco Bell           NaN
#
#                                               photos price rating  \
# 0  ['https://s3-media4.fl.yelpcdn.com/bphoto/LRHe...   NaN    4.5
# 1  ['https://s3-media2.fl.yelpcdn.com/bphoto/oUuV...   NaN    3.0
# 2  ['https://s3-media1.fl.yelpcdn.com/bphoto/7zsW...    $$    4.0
# 3  ['https://s3-media4.fl.yelpcdn.com/bphoto/LRHe...   NaN    4.5
# 4  ['https://s3-media1.fl.yelpcdn.com/bphoto/X5qg...     $    3.5
#
#    review_count            transactions  \
# 0          23.0                      []
# 1           2.0  ['pickup', 'delivery']
# 2          56.0                      []
# 3          23.0                      []
# 4          22.0            ['delivery']
#
#                                                  url
# 0  https://www.yelp.com/biz/one-eleven-food-hall-...
# 1  https://www.yelp.com/biz/karlas-kitchen-chicag...
# 2  https://www.yelp.com/biz/lincoln-quality-meat-...
# 3  https://www.yelp.com/biz/one-eleven-food-hall-...
# 4  https://www.yelp.com/biz/taco-bell-chicago-52?...
#
# [5 rows x 21 columns]

# %%
missing_DF = combine_csvs(missing_loc, False, out_file_missing)
# Out:
# importing: .DS_Store of length: 0 changing all businesses to closed =  False
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []
# importing: yelp_results_from_missing_after_1_wb.csv of length: 1626 changing all businesses to closed =  False
#   Unnamed: 0                             alias  business type  \
# 0          0      carmelo-s-taco-place-chicago     Restaurant
# 1          1  maggie-gyros-and-chicken-chicago     Restaurant
# 2          2           morenas-kitchen-chicago     Restaurant
# 3          3            northern-trust-chicago     Restaurant
# 4          4             deli-and-more-chicago  Grocery Store
#
#                                           categories  \
# 0             [{'alias': 'tacos', 'title': 'Tacos'}]
# 1  [{'alias': 'greek', 'title': 'Greek'}, {'alias...
# 2     [{'alias': 'dominican', 'title': 'Dominican'}]
# 3  [{'alias': 'banks', 'title': 'Banks & Credit U...
# 4  [{'alias': 'delis', 'title': 'Delis'}, {'alias...
#
#                                          coordinates   display_phone  \
# 0     {'latitude': 41.78663, 'longitude': -87.69294}  (773) 912-6808
# 1  {'latitude': 41.8092351, 'longitude': -87.6178...  (773) 924-1110
# 2   {'latitude': 41.916978, 'longitude': -87.753176}  (773) 622-7200
# 3   {'latitude': 41.881284, 'longitude': -87.632567}  (312) 630-6000
# 4  {'latitude': 41.9333267211914, 'longitude': -8...  (773) 857-3354
#
#                                                hours                      id  \
# 0  [{'open': [{'is_overnight': False, 'start': '0...  2OGQfIsT33WC7sCKdqKuuw
# 1                                                NaN  YULX9j3fdcLtUNYHax19JA
# 2  [{'open': [{'is_overnight': False, 'start': '1...  6hhWuqvuEIEescMsh807pw
# 3  [{'open': [{'is_overnight': False, 'start': '0...  VA1mmPgB4HcOpyw_-IA6DQ
# 4                                                NaN  YHToK3BYKGJudH_UNUCeVw
#
#                                            image_url is_claimed  ...  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/PHK-ap...       True  ...
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/OqmhFL...      False  ...
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/s0Kpss...       True  ...
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/XT0ycw...       True  ...
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/zwSHW4...       True  ...
#
#                                            messaging                    name  \
# 0                                                NaN    Carmelo’s Taco Place
# 1                                                NaN  Maggie Gyros & Chicken
# 2                                                NaN        Morena's Kitchen
# 3  {'url': 'https://www.yelp.com/raq/VA1mmPgB4HcO...          Northern Trust
# 4  {'url': 'https://www.yelp.com/raq/YHToK3BYKGJu...             Deli & More
#
#           phone                                             photos  price  \
# 0  1.773913e+10  ['https://s3-media2.fl.yelpcdn.com/bphoto/PHK-...    NaN
# 1  1.773924e+10  ['https://s3-media4.fl.yelpcdn.com/bphoto/Oqmh...    NaN
# 2  1.773623e+10  ['https://s3-media3.fl.yelpcdn.com/bphoto/s0Kp...      $
# 3  1.312631e+10  ['https://s3-media4.fl.yelpcdn.com/bphoto/XT0y...    NaN
# 4  1.773857e+10  ['https://s3-media3.fl.yelpcdn.com/bphoto/zwSH...     $$
#
#   rating review_count  special_hours            transactions  \
# 0    4.5         12.0            NaN  ['pickup', 'delivery']
# 1    2.5          5.0            NaN  ['delivery', 'pickup']
# 2    4.5         41.0            NaN  ['pickup', 'delivery']
# 3    2.5          8.0            NaN                      []
# 4    4.5          9.0            NaN  ['pickup', 'delivery']
#
#                                                  url
# 0  https://www.yelp.com/biz/carmelo-s-taco-place-...
# 1  https://www.yelp.com/biz/maggie-gyros-and-chic...
# 2  https://www.yelp.com/biz/morenas-kitchen-chica...
# 3  https://www.yelp.com/biz/northern-trust-chicag...
# 4  https://www.yelp.com/biz/deli-and-more-chicago...
#
# [5 rows x 22 columns]
# importing: yelp_results_from_missing_after_2_wb.csv of length: 1234 changing all businesses to closed =  False
#   Unnamed: 0                             alias  business type  \
# 0          0      carmelo-s-taco-place-chicago     Restaurant
# 1          1  maggie-gyros-and-chicken-chicago     Restaurant
# 2          2           morenas-kitchen-chicago     Restaurant
# 3          3            northern-trust-chicago     Restaurant
# 4          4             deli-and-more-chicago  Grocery Store
#
#                                           categories  \
# 0             [{'alias': 'tacos', 'title': 'Tacos'}]
# 1  [{'alias': 'greek', 'title': 'Greek'}, {'alias...
# 2     [{'alias': 'dominican', 'title': 'Dominican'}]
# 3  [{'alias': 'banks', 'title': 'Banks & Credit U...
# 4  [{'alias': 'delis', 'title': 'Delis'}, {'alias...
#
#                                          coordinates   display_phone error  \
# 0     {'latitude': 41.78663, 'longitude': -87.69294}  (773) 912-6808   NaN
# 1  {'latitude': 41.8092351, 'longitude': -87.6178...  (773) 924-1110   NaN
# 2   {'latitude': 41.916978, 'longitude': -87.753176}  (773) 622-7200   NaN
# 3   {'latitude': 41.881284, 'longitude': -87.632567}  (312) 630-6000   NaN
# 4  {'latitude': 41.9333267211914, 'longitude': -8...  (773) 857-3354   NaN
#
#                                                hours                      id  \
# 0  [{'open': [{'is_overnight': False, 'start': '0...  2OGQfIsT33WC7sCKdqKuuw
# 1                                                NaN  YULX9j3fdcLtUNYHax19JA
# 2  [{'open': [{'is_overnight': False, 'start': '1...  6hhWuqvuEIEescMsh807pw
# 3  [{'open': [{'is_overnight': False, 'start': '0...  VA1mmPgB4HcOpyw_-IA6DQ
# 4                                                NaN  YHToK3BYKGJudH_UNUCeVw
#
#                                            image_url  ...  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/PHK-ap...  ...
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/OqmhFL...  ...
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/s0Kpss...  ...
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/XT0ycw...  ...
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/zwSHW4...  ...
#
#                                            messaging                    name  \
# 0                                                NaN    Carmelo’s Taco Place
# 1                                                NaN  Maggie Gyros & Chicken
# 2                                                NaN        Morena's Kitchen
# 3  {'url': 'https://www.yelp.com/raq/VA1mmPgB4HcO...          Northern Trust
# 4  {'url': 'https://www.yelp.com/raq/YHToK3BYKGJu...             Deli & More
#
#           phone                                             photos price  \
# 0  1.773913e+10  ['https://s3-media2.fl.yelpcdn.com/bphoto/PHK-...   NaN
# 1  1.773924e+10  ['https://s3-media4.fl.yelpcdn.com/bphoto/Oqmh...   NaN
# 2  1.773623e+10  ['https://s3-media3.fl.yelpcdn.com/bphoto/s0Kp...     $
# 3  1.312631e+10  ['https://s3-media4.fl.yelpcdn.com/bphoto/XT0y...   NaN
# 4  1.773857e+10  ['https://s3-media3.fl.yelpcdn.com/bphoto/zwSH...    $$
#
#    rating review_count special_hours            transactions  \
# 0     4.5         12.0           NaN  ['pickup', 'delivery']
# 1     2.5          5.0           NaN  ['delivery', 'pickup']
# 2     4.5         41.0           NaN  ['pickup', 'delivery']
# 3     2.5          8.0           NaN                      []
# 4     4.5          9.0           NaN  ['pickup', 'delivery']
#
#                                                  url
# 0  https://www.yelp.com/biz/carmelo-s-taco-place-...
# 1  https://www.yelp.com/biz/maggie-gyros-and-chic...
# 2  https://www.yelp.com/biz/morenas-kitchen-chica...
# 3  https://www.yelp.com/biz/northern-trust-chicag...
# 4  https://www.yelp.com/biz/deli-and-more-chicago...
#
# [5 rows x 23 columns]

# %%
full_DF = combine_csvs(ALL_loc, False, out_file_ALL)
# Out:
# importing: all_OG_yelp.csv of length: 11043 changing all businesses to closed =  False
#    Unnamed: 0                                  alias  \
# 0        8344                   burger-king-skokie-2
# 1       20907  xochimilco-mexican-restaurant-chicago
# 2       14901                altos-de-jalisco-cicero
# 3       21151                     los-flacos-chicago
# 4       20536                      dunkin-chicago-11
#
#                                           categories  \
# 0  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...
# 1         [{'alias': 'mexican', 'title': 'Mexican'}]
# 2         [{'alias': 'mexican', 'title': 'Mexican'}]
# 3         [{'alias': 'mexican', 'title': 'Mexican'}]
# 4  [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...
#
#                                          coordinates   display_phone  \
# 0      {'latitude': 42.01167, 'longitude': -87.7603}             NaN
# 1  {'latitude': 41.9616665, 'longitude': -87.6802...    +17736611534
# 2  {'latitude': 41.8654202, 'longitude': -87.7707...  (708) 683-5094
# 3  {'latitude': 41.9685047, 'longitude': -87.7239...    +18728060025
# 4  {'latitude': 41.9534026, 'longitude': -87.7361...    +17737773041
#
#            distance hours                      id  \
# 0  77.9121466730748   NaN  --YT_AvcLpZ3Gd3mCgvbKQ
# 1    (773) 661-1534   NaN  --Yw337vTC4fLKRCaw-PLQ
# 2  82.7839611696486   NaN  --b5l3s3iqmg5GVYGVlo1A
# 3    (872) 806-0025   NaN  --li1INYTksr8rYmhP_wqQ
# 4    (773) 777-3041   NaN  -0f8Uv_vz_bAxjrN0i4O-A
#
#                                            image_url  is_claimed  ...  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/GPb74S...         NaN  ...
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/T0E_7I...         NaN  ...
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/fDlvIf...         NaN  ...
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/zaX_KT...         NaN  ...
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/dhf2Iz...         NaN  ...
#
#    messaging                           name  \
# 0        NaN                    Burger King
# 1        NaN  XOchimilco Mexican Restaurant
# 2        NaN               Altos de Jalisco
# 3        NaN                     Los Flacos
# 4        NaN                        Dunkin'
#
#                                                phone photos  \
# 0                                                NaN    NaN
# 1  {'address1': '2030-32 W Montrose Ave', 'addres...    NaN
# 2                                       +17086835094    NaN
# 3  {'address1': '3818 W Lawrence Ave', 'address2'...    NaN
# 4  {'address1': '4313 W Irving Park Rd', 'address...    NaN
#
#                 price rating review_count  special_hours  \
# 0                   $    1.5         28.0            NaN
# 1   61.86234143054439    5.0        155.0            NaN
# 2                 NaN    4.0          9.0            NaN
# 3  128.24344256046712    3.5         57.0            NaN
# 4   156.8678536226531    1.5         15.0            NaN
#
#              transactions                                                url
# 0            ['delivery']  https://www.yelp.com/biz/burger-king-skokie-2?...
# 1  ['delivery', 'pickup']  https://www.yelp.com/biz/xochimilco-mexican-re...
# 2                      []  https://www.yelp.com/biz/altos-de-jalisco-cice...
# 3  ['delivery', 'pickup']  https://www.yelp.com/biz/los-flacos-chicago?ad...
# 4            ['delivery']  https://www.yelp.com/biz/dunkin-chicago-11?adj...
#
# [5 rows x 22 columns]
# importing: .DS_Store of length: 0 changing all businesses to closed =  False
#   Unnamed: 0                                  alias  \
# 0       8344                   burger-king-skokie-2
# 1      20907  xochimilco-mexican-restaurant-chicago
# 2      14901                altos-de-jalisco-cicero
# 3      21151                     los-flacos-chicago
# 4      20536                      dunkin-chicago-11
#
#                                           categories  \
# 0  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...
# 1         [{'alias': 'mexican', 'title': 'Mexican'}]
# 2         [{'alias': 'mexican', 'title': 'Mexican'}]
# 3         [{'alias': 'mexican', 'title': 'Mexican'}]
# 4  [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...
#
#                                          coordinates   display_phone  \
# 0      {'latitude': 42.01167, 'longitude': -87.7603}             NaN
# 1  {'latitude': 41.9616665, 'longitude': -87.6802...    +17736611534
# 2  {'latitude': 41.8654202, 'longitude': -87.7707...  (708) 683-5094
# 3  {'latitude': 41.9685047, 'longitude': -87.7239...    +18728060025
# 4  {'latitude': 41.9534026, 'longitude': -87.7361...    +17737773041
#
#            distance hours                      id  \
# 0  77.9121466730748   NaN  --YT_AvcLpZ3Gd3mCgvbKQ
# 1    (773) 661-1534   NaN  --Yw337vTC4fLKRCaw-PLQ
# 2  82.7839611696486   NaN  --b5l3s3iqmg5GVYGVlo1A
# 3    (872) 806-0025   NaN  --li1INYTksr8rYmhP_wqQ
# 4    (773) 777-3041   NaN  -0f8Uv_vz_bAxjrN0i4O-A
#
#                                            image_url  is_claimed  ...  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/GPb74S...         NaN  ...
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/T0E_7I...         NaN  ...
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/fDlvIf...         NaN  ...
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/zaX_KT...         NaN  ...
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/dhf2Iz...         NaN  ...
#
#    messaging                           name  \
# 0        NaN                    Burger King
# 1        NaN  XOchimilco Mexican Restaurant
# 2        NaN               Altos de Jalisco
# 3        NaN                     Los Flacos
# 4        NaN                        Dunkin'
#
#                                                phone photos  \
# 0                                                NaN    NaN
# 1  {'address1': '2030-32 W Montrose Ave', 'addres...    NaN
# 2                                       +17086835094    NaN
# 3  {'address1': '3818 W Lawrence Ave', 'address2'...    NaN
# 4  {'address1': '4313 W Irving Park Rd', 'address...    NaN
#
#                 price rating review_count  special_hours  \
# 0                   $    1.5         28.0            NaN
# 1   61.86234143054439    5.0        155.0            NaN
# 2                 NaN    4.0          9.0            NaN
# 3  128.24344256046712    3.5         57.0            NaN
# 4   156.8678536226531    1.5         15.0            NaN
#
#              transactions                                                url
# 0            ['delivery']  https://www.yelp.com/biz/burger-king-skokie-2?...
# 1  ['delivery', 'pickup']  https://www.yelp.com/biz/xochimilco-mexican-re...
# 2                      []  https://www.yelp.com/biz/altos-de-jalisco-cice...
# 3  ['delivery', 'pickup']  https://www.yelp.com/biz/los-flacos-chicago?ad...
# 4            ['delivery']  https://www.yelp.com/biz/dunkin-chicago-11?adj...
#
# [5 rows x 22 columns]
# importing: missing_all_wb.csv of length: 2793 changing all businesses to closed =  False
#   Unnamed: 0                                  alias business type  \
# 0       8344                   burger-king-skokie-2           NaN
# 1      20907  xochimilco-mexican-restaurant-chicago           NaN
# 2      14901                altos-de-jalisco-cicero           NaN
# 3      21151                     los-flacos-chicago           NaN
# 4      20536                      dunkin-chicago-11           NaN
#
#                                           categories  \
# 0  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...
# 1         [{'alias': 'mexican', 'title': 'Mexican'}]
# 2         [{'alias': 'mexican', 'title': 'Mexican'}]
# 3         [{'alias': 'mexican', 'title': 'Mexican'}]
# 4  [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...
#
#                                          coordinates   display_phone  \
# 0      {'latitude': 42.01167, 'longitude': -87.7603}             NaN
# 1  {'latitude': 41.9616665, 'longitude': -87.6802...    +17736611534
# 2  {'latitude': 41.8654202, 'longitude': -87.7707...  (708) 683-5094
# 3  {'latitude': 41.9685047, 'longitude': -87.7239...    +18728060025
# 4  {'latitude': 41.9534026, 'longitude': -87.7361...    +17737773041
#
#            distance error hours                      id  ... messaging  \
# 0  77.9121466730748   NaN   NaN  --YT_AvcLpZ3Gd3mCgvbKQ  ...       NaN
# 1    (773) 661-1534   NaN   NaN  --Yw337vTC4fLKRCaw-PLQ  ...       NaN
# 2  82.7839611696486   NaN   NaN  --b5l3s3iqmg5GVYGVlo1A  ...       NaN
# 3    (872) 806-0025   NaN   NaN  --li1INYTksr8rYmhP_wqQ  ...       NaN
# 4    (773) 777-3041   NaN   NaN  -0f8Uv_vz_bAxjrN0i4O-A  ...       NaN
#
#                             name  \
# 0                    Burger King
# 1  XOchimilco Mexican Restaurant
# 2               Altos de Jalisco
# 3                     Los Flacos
# 4                        Dunkin'
#
#                                                phone photos  \
# 0                                                NaN    NaN
# 1  {'address1': '2030-32 W Montrose Ave', 'addres...    NaN
# 2                                       +17086835094    NaN
# 3  {'address1': '3818 W Lawrence Ave', 'address2'...    NaN
# 4  {'address1': '4313 W Irving Park Rd', 'address...    NaN
#
#                 price rating review_count special_hours  \
# 0                   $    1.5         28.0           NaN
# 1   61.86234143054439    5.0        155.0           NaN
# 2                 NaN    4.0          9.0           NaN
# 3  128.24344256046712    3.5         57.0           NaN
# 4   156.8678536226531    1.5         15.0           NaN
#
#              transactions                                                url
# 0            ['delivery']  https://www.yelp.com/biz/burger-king-skokie-2?...
# 1  ['delivery', 'pickup']  https://www.yelp.com/biz/xochimilco-mexican-re...
# 2                      []  https://www.yelp.com/biz/altos-de-jalisco-cice...
# 3  ['delivery', 'pickup']  https://www.yelp.com/biz/los-flacos-chicago?ad...
# 4            ['delivery']  https://www.yelp.com/biz/dunkin-chicago-11?adj...
#
# [5 rows x 24 columns]
# importing: closed_all_wb.csv of length: 532 changing all businesses to closed =  False
#   Unnamed: 0                                  alias business type  \
# 0       8344                   burger-king-skokie-2           NaN
# 1      20907  xochimilco-mexican-restaurant-chicago           NaN
# 2      14901                altos-de-jalisco-cicero           NaN
# 3      21151                     los-flacos-chicago           NaN
# 4      20536                      dunkin-chicago-11           NaN
#
#                                           categories  \
# 0  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...
# 1         [{'alias': 'mexican', 'title': 'Mexican'}]
# 2         [{'alias': 'mexican', 'title': 'Mexican'}]
# 3         [{'alias': 'mexican', 'title': 'Mexican'}]
# 4  [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...
#
#                                          coordinates   display_phone  \
# 0      {'latitude': 42.01167, 'longitude': -87.7603}             NaN
# 1  {'latitude': 41.9616665, 'longitude': -87.6802...    +17736611534
# 2  {'latitude': 41.8654202, 'longitude': -87.7707...  (708) 683-5094
# 3  {'latitude': 41.9685047, 'longitude': -87.7239...    +18728060025
# 4  {'latitude': 41.9534026, 'longitude': -87.7361...    +17737773041
#
#            distance error hours                      id  ... messaging  \
# 0  77.9121466730748   NaN   NaN  --YT_AvcLpZ3Gd3mCgvbKQ  ...       NaN
# 1    (773) 661-1534   NaN   NaN  --Yw337vTC4fLKRCaw-PLQ  ...       NaN
# 2  82.7839611696486   NaN   NaN  --b5l3s3iqmg5GVYGVlo1A  ...       NaN
# 3    (872) 806-0025   NaN   NaN  --li1INYTksr8rYmhP_wqQ  ...       NaN
# 4    (773) 777-3041   NaN   NaN  -0f8Uv_vz_bAxjrN0i4O-A  ...       NaN
#
#                             name  \
# 0                    Burger King
# 1  XOchimilco Mexican Restaurant
# 2               Altos de Jalisco
# 3                     Los Flacos
# 4                        Dunkin'
#
#                                                phone photos  \
# 0                                                NaN    NaN
# 1  {'address1': '2030-32 W Montrose Ave', 'addres...    NaN
# 2                                       +17086835094    NaN
# 3  {'address1': '3818 W Lawrence Ave', 'address2'...    NaN
# 4  {'address1': '4313 W Irving Park Rd', 'address...    NaN
#
#                 price rating review_count special_hours  \
# 0                   $    1.5         28.0           NaN
# 1   61.86234143054439    5.0        155.0           NaN
# 2                 NaN    4.0          9.0           NaN
# 3  128.24344256046712    3.5         57.0           NaN
# 4   156.8678536226531    1.5         15.0           NaN
#
#              transactions                                                url
# 0            ['delivery']  https://www.yelp.com/biz/burger-king-skokie-2?...
# 1  ['delivery', 'pickup']  https://www.yelp.com/biz/xochimilco-mexican-re...
# 2                      []  https://www.yelp.com/biz/altos-de-jalisco-cice...
# 3  ['delivery', 'pickup']  https://www.yelp.com/biz/los-flacos-chicago?ad...
# 4            ['delivery']  https://www.yelp.com/biz/dunkin-chicago-11?adj...
#
# [5 rows x 24 columns]

# %%
len(full_DF) #12 465
# Out:
# 12465
